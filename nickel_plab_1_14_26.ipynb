# %% [markdown]
# <a href="https://colab.research.google.com/github/jacknickel-prog/CS302/blob/main/nickel_plab_1_14_26.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
a = 10
b = a
a = 20
print(b)
# Out:
# 10

# %%
def f(x):
  x = x + 1
  print(x)

n = 5
f(n)
print(n)
# Out:
# 6
# 5

# %%
x = 5
print(id(x))
x += 1
print(id(x))
# Out:
# 11654504
# 11654536

# %%
lst = [1,2]
print(id(lst))
lst.append(3)
print(id(lst))
# Out:
# 132609005638272
# 132609005638272

# %%
def change(x):
  x = x + 10

a = 5
change(a)
print(a)
# Out:
# 5

# %%
def change(lst):
  lst.append(99)

data = [1,2]
change(data)
print(data)
# Out:
# [1, 2, 99]

# %%
def reset_wrong(lst):
  lst = []

def reset_right(lst):
  lst.clear()

data = [1,2,3]
reset_wrong(data)
print(data)

reset_right(data)
print(data)
# Out:
# [1, 2, 3]
# []

# %%
def demo(x):
  print(id(x))
  x.append(5)
  print(id(x))

lst = [1,2]
print(id(lst))
demo(lst)
# Out:
# 136512095622272
# 136512095622272
# 136512095622272

# %%
a = [1,2]
b = [1,2]

print(a == b)
print(a is b)
# Out:
# True
# False

# %%
x = [1,2]
print(id(x))
x = [3,4]
print(id(x))
# Out:
# 136511708113152
# 136511708106880
